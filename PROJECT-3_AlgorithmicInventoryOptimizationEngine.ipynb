# %% [markdown]
# # 🗄️ Project 3: Algorithmic Inventory Optimization Engine
# ## Prescriptive Analytics: Data-Driven Capital Efficiency & Replenishment Automation
#
# ### 1. Project Overview
# Following the descriptive diagnostics of the Supply Chain Optimization (Project 1) and the high-accuracy machine learning predictions of the Forecasting Engine (Project 2), this project executes the final phase of the advanced analytics lifecycle: **Prescriptive Optimization**.
#
# Instead of relying on retrospective dashboards or manual spreadsheet reviews, this phase implements a production-grade relational database engine to translate consumer demand signals directly into automated, self-healing operational actions. By deploying mathematical safety stock models and dynamic procurement thresholds directly onto the server layer, this engine completely automates warehouse replenishment workflows, eliminates localized stockout vulnerabilities, and systematically frees up trapped working capital.
#
# ### 2. Business Objectives
# * **Automate Procurement Guardrails:** Establish algorithmic thresholds to dynamically trigger replenishment cycles exactly when inventory levels cross mathematical lines-in-the-sand.
# * **Maximize Working Capital Efficiency:** Identify overstocked distribution nodes to eliminate unnecessary storage overhead, prevent product expiration, and extract frozen liquidity.
# * **Provide Real-Time Operational Directives:** Standardize raw, messy warehouse metrics into a single, unambiguous status pipeline that grants local warehouse managers immediate visibility into inventory health.
#
# ### 3. Prescriptive SQL Architecture & Database Methodology
# * **Database Ingestion & Schema Engineering:** Establish a high-throughput extraction-transformation-loading (ETL) pipeline using Python to stream production records directly into a localized relational database instance.
# * **Multi-Stage Mathematical Aggregation:** Utilize advanced **Common Table Expressions (CTEs)** and relational window functions to construct a multi-tiered calculations pipeline without pre-processing data in Python.
# * **Statistical Volatility Modeling:** Calculate the standard deviation of consumer consumption patterns to establish variable safety stock buffers designed to withstand supply chain disruptions and vendor lead-time instability.
# * **Automated Conditional Logic Engine:** Deploy nested `CASE WHEN` logic blocks to continuously score every active SKU into a rolling operational status category (*Critical Stockout*, *Reorder Immediately*, *Healthy*, or *Overstocked*).

# %% [markdown]
# ## Connect to SQL Server

# %%
import pandas as pd
from sqlalchemy import create_engine

# 1. Read your clean dataset
df = pd.read_csv('fully_cleaned_supply_chain_data_new.csv')

# 2. Update with your real database credentials
# Format: 'postgresql://username:password@localhost:5432/database_name'
POSTGRES_URL = 'postgresql://postgres:H4l0H4l0bandoeng@localhost:5432/postgres'

# 3. Stream data to local server
engine = create_engine(POSTGRES_URL)
df.to_sql('supply_chain', engine, if_exists='replace', index=False)
print("🎉 Success! The 'supply_chain' table is live inside pgAdmin!")
# Out:
# 🎉 Success! The 'supply_chain' table is live inside pgAdmin!
